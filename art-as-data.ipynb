# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# Use the kagglehub client library to attach Kaggle resources like competitions, datasets, and models to your session
# Learn more about kagglehub: https://github.com/Kaggle/kagglehub/blob/main/README.md

import kagglehub
# kagglehub.dataset_download('<owner>/<dataset-slug>')
# Out:
# /kaggle/input/datasets/mamdouhsamir/mondrian-painting-features/mondrian-painting-features.csv
# /kaggle/input/datasets/mamdouhsamir/mondrian-painting-info/mondrian-painting-info.csv
# /kaggle/input/datasets/mamdouhsamir/fp26-features/fp26-features.csv

# %%
#Loading the data

#Import pandas.
#Load the features data.
#Display the dataframe.


import pandas as pd
features = pd.read_csv('/kaggle/input/datasets/mamdouhsamir/mondrian-painting-features/mondrian-painting-features.csv')
features #display the dataframe
# Out:
#      painting_id feature    x    y  width  height  color      rgb
# 0           b104    rect    0    0    146      13  white  #ced2ca
# 1           b104    rect  151    0    576      13   gray  #a4a7a7
# 2           b104    rect  732    0    278     129   gray  #c8c9c7
# 3           b104    rect    0   18    146     468  white  #cfd0ce
# 4           b104    rect  151   18    107     111  black  #151d16
# ...          ...     ...  ...  ...    ...     ...    ...      ...
# 3199        b296  v-line  620    0     19     825  black  #000000
# 3200        b296  v-line   49  508     19      79  black  #000000
# 3201        b296  h-line    0  268    711      19  black  #000000
# 3202        b296  h-line    0  489    711      19  black  #000000
# 3203        b296  h-line    0  679     11      28  black  #000000
#
# [3204 rows x 8 columns]

# %%
#Find all the features for painting b104.

features.query('painting_id == "b104"')
# Out:
#    painting_id feature    x    y  width  height   color      rgb
# 0         b104    rect    0    0    146      13   white  #ced2ca
# 1         b104    rect  151    0    576      13    gray  #a4a7a7
# 2         b104    rect  732    0    278     129    gray  #c8c9c7
# 3         b104    rect    0   18    146     468   white  #cfd0ce
# 4         b104    rect  151   18    107     111   black  #151d16
# 5         b104    rect  263   18    464     111    blue  #233c55
# 6         b104    rect  151  134    380     143    gray  #abafaf
# 7         b104    rect  536  134    191     143     red  #b93e0b
# 8         b104    rect  732  134    212     143   black  #111712
# 9         b104    rect  949  134     61     143    blue  #233c55
# 10        b104    rect  151  282    107     204   black  #151d16
# 11        b104    rect  263  282    268     204  yellow  #d2c300
# 12        b104    rect  536  282    191     343    blue  #233c55
# 13        b104    rect  732  282    212     343     red  #b93e0b
# 14        b104    rect  949  282     61     484    gray  #979b96
# 15        b104    rect    0  491    146     452    gray  #abacae
# 16        b104    rect  151  491    107     452    gray  #abacae
# 17        b104    rect  263  491    268     134  yellow  #d2c300
# 18        b104    rect  263  630    268     136     red  #b93e0b
# 19        b104    rect  536  630    191     136   white  #cfd0ce
# 20        b104    rect  732  630    212     136  yellow  #d2c300
# 21        b104    rect  263  771    268     172   black  #0e140e
# 22        b104    rect  536  771    191     172    gray  #9fa3a3
# 23        b104    rect  732  771    212     172    blue  #233c55
# 24        b104    rect  949  771     61     236     red  #b93e0b
# 25        b104    rect    0  948    258      59  yellow  #cab901
# 26        b104    rect  263  948    464      59   white  #c4c6c5
# 27        b104    rect  732  948    212      59   black  #0e140e
# 28        b104  h-line    0   13    727       5   black  #000000
# 29        b104  h-line  151  129    859       5   black  #000000
# 30        b104  h-line  151  277    859       5   black  #000000
# 31        b104  h-line    0  486    531       5   black  #000000
# 32        b104  h-line  263  625    681       5   black  #000000
# 33        b104  h-line  263  766    747       5   black  #000000
# 34        b104  h-line    0  943    944       5   black  #000000
# 35        b104  v-line  146    0      5     943   black  #000000
# 36        b104  v-line  727    0      5    1007   black  #000000
# 37        b104  v-line  258   18      5     111   black  #000000
# 38        b104  v-line  531  134      5     809   black  #000000
# 39        b104  v-line  944  134      5     873   black  #000000
# 40        b104  v-line  258  282      5     725   black  #000000

# %%
#Load the painting info data.
#Display the dataframe.

painting_info = pd.read_csv('/kaggle/input/datasets/mamdouhsamir/mondrian-painting-info/mondrian-painting-info.csv')
painting_info #display the dataframe
# Out:
#     painting_id  year                                   title  width  height
# 0          b104  1920                                  No. VI   1010    1007
# 1          b105  1920                           Composition A    918     900
# 2          b106  1920                           Composition B    575     677
# 3          b107  1920                           Composition C    610     603
# 4          b108  1920                           Composition I    646     750
# ..          ...   ...                                     ...    ...     ...
# 131        b292  1939                       Composition no. 1   1023    1052
# 132        b293  1939  Composition of red, blue and white: II    330     435
# 133        b294  1939                        Trafalgar Square   1200    1452
# 134        b295  1939                       Composition no. 8    681     752
# 135        b296  1940                      Composition no. 11    711     825
#
# [136 rows x 5 columns]

# %%
#Turning data into pictures

import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

def draw_mondrian( painting_id ):
    rects = features.query('painting_id == @painting_id')
    total_width = rects.eval("x + width").max()
    total_height = rects.eval("y + height").max()
    
    fig, ax = plt.subplots()
    
    for (idx, row) in rects.iterrows():
        x, y, w, h, rgb = row[['x','y','width','height','rgb']]
        patch = mpatches.Rectangle((x, y), w, h, facecolor=rgb)
        ax.add_patch(patch)
    
    ax.axis([0, total_width, 0, total_height])
    ax.set_aspect('equal')
    ax.axis('off')
    fig.text(0.5, 0.01, painting_id, ha="center", fontsize=14)
    fig.show()

draw_mondrian('b104')

# %%
#Comparing complexity
#Draw any two Mondrian paintings.

draw_mondrian('b105')
draw_mondrian('b212')

# %%
#Group the features by painting_id.
#Count the number of rows in each group.
#Display the counts.

sizes = features.groupby('painting_id').size()
sizes #display the result
# Out:
# painting_id
# b104    41
# b105    42
# b106    41
# b107    44
# b108    44
#         ..
# b292    31
# b293    26
# b294    62
# b295    47
# b296    49
# Length: 136, dtype: int64

# %%
#Reset the index and name the values 'complexity'.
#Name the new dataframe 'complexity_df'.
#Display the dataframe.

complexity_df = sizes.reset_index(name='complexity')
complexity_df
# Out:
#     painting_id  complexity
# 0          b104          41
# 1          b105          42
# 2          b106          41
# 3          b107          44
# 4          b108          44
# ..          ...         ...
# 131        b292          31
# 132        b293          26
# 133        b294          62
# 134        b295          47
# 135        b296          49
#
# [136 rows x 2 columns]

# %%
#Merging data
#Merge 'complexity_df' into 'painting_info'.
#Display the result.

painting_info = painting_info.merge(complexity_df, on='painting_id', how='left')
painting_info #display
# Out:
#     painting_id  year                                   title  width  height  \
# 0          b104  1920                                  No. VI   1010    1007
# 1          b105  1920                           Composition A    918     900
# 2          b106  1920                           Composition B    575     677
# 3          b107  1920                           Composition C    610     603
# 4          b108  1920                           Composition I    646     750
# ..          ...   ...                                     ...    ...     ...
# 131        b292  1939                       Composition no. 1   1023    1052
# 132        b293  1939  Composition of red, blue and white: II    330     435
# 133        b294  1939                        Trafalgar Square   1200    1452
# 134        b295  1939                       Composition no. 8    681     752
# 135        b296  1940                      Composition no. 11    711     825
#
#      complexity
# 0            41
# 1            42
# 2            41
# 3            44
# 4            44
# ..          ...
# 131          31
# 132          26
# 133          62
# 134          47
# 135          49
#
# [136 rows x 6 columns]

# %%
#Plotting complexity over time

#Import matplotlib.pyplot.
#Create a scatter plot of complexity over time.
#Label the axes.

import matplotlib.pyplot as plt

plt.scatter(painting_info['year'], painting_info['complexity'])

plt.xlabel('Year')
plt.ylabel('Complexity')
# Out:
# Text(0, 0.5, 'Complexity')

# %%
#Detecting possible fake paintings

#Load the features for fake painting 1926.
#Display the Dataframe.

fp26_features = pd.read_csv('/kaggle/input/datasets/mamdouhsamir/fp26-features/fp26-features.csv')
fp26_features #display the table
# Out:
#    painting_id feature    x    y  width  height   color      rgb
# 0         fp26    rect    0    0     34      92   white  #fafafa
# 1         fp26    rect   41    0    267      22   white  #f9f9f9
# 2         fp26    rect  317    0    309      22   white  #fafafa
# 3         fp26    rect  634    0     38     261   white  #fafafa
# 4         fp26    rect  680    0     32     261  yellow  #fcf202
# 5         fp26    rect   41   30    267      62    blue  #2b529d
# 6         fp26    rect  317   30    109      62   white  #fafafa
# 7         fp26    rect  433   30    193      62    blue  #2c529d
# 8         fp26    rect    0  100     34     236   black  #020202
# 9         fp26    rect   41  100     81     236   white  #fbfbfb
# 10        fp26    rect  130  100     31     397   black  #020202
# 11        fp26    rect  169  100    101     161   white  #fafafa
# 12        fp26    rect  279  100     29     161   white  #fafafa
# 13        fp26    rect  317  100    109     161  yellow  #fbf102
# 14        fp26    rect  433  100    147     161     red  #f30100
# 15        fp26    rect  587  100     39     161     red  #f40100
# 16        fp26    rect  169  269     33      67  yellow  #fcf203
# 17        fp26    rect  210  269     98      67     red  #f40101
# 18        fp26    rect  317  269    109      67    blue  #2c529e
# 19        fp26    rect  433  269    147      67   white  #fafafa
# 20        fp26    rect  587  269     39      67   white  #fafafa
# 21        fp26    rect  634  269     78      67   black  #030303
# 22        fp26    rect    0  344     34     153   white  #fafafa
# 23        fp26    rect   41  344     81     153     red  #f40101
# 24        fp26    rect  169  344     33     202  yellow  #fcf203
# 25        fp26    rect  210  344    175     118   white  #fafafa
# 26        fp26    rect  393  344    122     118   white  #fafafa
# 27        fp26    rect  523  344     57     118    blue  #2c529e
# 28        fp26    rect  587  344     39     118  yellow  #fcf303
# 29        fp26    rect  634  344     78     118   white  #fafafa
# 30        fp26    rect  210  470     98      76     red  #f30000
# 31        fp26    rect  317  470    198      76   black  #030303
# 32        fp26    rect  523  470    189      76   white  #fafafa
# 33        fp26    rect    0  505    161      41   white  #fafafa
# 34        fp26  v-line   34    0      7     501   black  #000000
# 35        fp26  v-line  308    0      9     340   black  #000000
# 36        fp26  v-line  626    0      8     466   black  #000000
# 37        fp26  v-line  672    0      8     265   black  #000000
# 38        fp26  v-line  426   26      7     314   black  #000000
# 39        fp26  v-line  122   96      8     405   black  #000000
# 40        fp26  v-line  161   96      8     450   black  #000000
# 41        fp26  v-line  202  265      8     281   black  #000000
# 42        fp26  v-line  385  340      8     126   black  #000000
# 43        fp26  v-line  515  340      8     206   black  #000000
# 44        fp26  h-line   38   22    592       8   black  #000000
# 45        fp26  h-line    0   92    630       8   black  #000000
# 46        fp26  h-line  165  261    547       8   black  #000000
# 47        fp26  h-line    0  336    126       8   black  #000000
# 48        fp26  h-line  165  336    547       8   black  #000000
# 49        fp26  h-line  206  462    506       8   black  #000000
# 50        fp26  h-line    0  497    166       8   black  #000000
# 51        fp26  v-line  270   96      9     169   black  #000000
# 52        fp26  v-line  580   96      7     370   black  #000000
# 53        fp26  v-line  308  466      9      80   black  #000000

# %%
#Recreate the scatter plot from earlier.
plt.scatter(painting_info['year'], painting_info['complexity'])

#Plot the new point as a red square.
plt.scatter(x=1926, y=54, color='red', marker='s')

#Label the axes.
plt.xlabel('Year')
plt.ylabel('Complexity')
# Out:
# Text(0, 0.5, 'Complexity')
